# %% [markdown]
# <a href="https://colab.research.google.com/github/EdVKu/MeIA-2023/blob/main/Reto3_EduardoVazquezKuri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En primer lugar, se recabaron Los datos brutos de cada codón, a partir del archivo .csv

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

codon = pd.read_csv('/content/codon_usage.csv', sep = '\t', header = 0)

# %% [markdown]
# Una Fila de números fue guardada dentro de Los nombres de columnas, por lo que se generó una lista de enteros del tamaño de las columnas del DataFrame. Finalmente, se fijaron Los nombres de las columnas usando esta lista.

# %%
nombres = list(range(64))
codon.columns = nombres

# %%
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.000000  0.018349  0.000000  0.009174  0.064220  0.009174  0.018349
# 1     0.002589  0.039148  0.031852  0.005480  0.000776  0.003668  0.000358
# 2     0.001891  0.000630  0.000315  0.002206  0.025528  0.008824  0.010085
# 3     0.001413  0.001413  0.000000  0.007063  0.012996  0.000989  0.004662
# 4     0.022581  0.061290  0.024193  0.019355  0.001613  0.000000  0.004839
# ...        ...       ...       ...       ...       ...       ...       ...
# 4918  0.003566  0.023335  0.006949  0.018750  0.002336  0.001639  0.004912
# 4919  0.000000  0.011976  0.005988  0.021956  0.009980  0.000000  0.003992
# 4920  0.002162  0.002162  0.000432  0.009082  0.016434  0.001297  0.009082
# 4921  0.004504  0.004504  0.002252  0.012669  0.012106  0.003097  0.009854
# 4922  0.003755  0.023118  0.006968  0.018584  0.002525  0.001807  0.005222
#
# ...
